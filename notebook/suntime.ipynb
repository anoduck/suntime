# %% [markdown]
# # Suntime Colab Notebook

# %% [markdown]
# The purpose of this notebook is to leverage the computational power provided by Google Colab to process photos for extraction of time date information from which they were created. None of this would be possible if the previous work had not been discovered.

# %% [markdown]
# ## Previous work

# %% [markdown]
# ### Setup the Environment

# %%
from importlib import
